# %%
library(data.table)
library(tidyverse)

# %%
setwd('C:/Users/fleur/2021 P-SAT/주제분석/주제분석 1주차/데이터')

# %%
prov = fread('provinceee.csv', data.table = FALSE)[,-1]
hos = fread('동물병원 정보.csv', data.table = FALSE)

# %%
prov[prov['sigungu'] == '세종특별자치시 세종특별자치시', 'sigungu'] = '세종특별자치시'

# %%
hos %>% is.na %>% sum()
# Out:
# [1] 0

# %%
# sigungu별 동물병원 개수
hos = hos %>% group_by(sigungu) %>% summarise(hospital_num = n())
hos
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#     sigungu               hospital_num
# 1   강원도 강릉시          15
# 2   강원도 고성군           3
# 3   강원도 동해시           4
# 4   강원도 삼척시           4
# 5   강원도 속초시           8
# 6   강원도 양구군           2
# 7   강원도 양양군           2
# 8   강원도 영월군           4
# 9   강원도 원주시          28
# 10  강원도 인제군           4
# 11  강원도 정선군           4
# 12  강원도 철원군           6
# 13  강원도 춘천시          26
# 14  강원도 태백시           2
# 15  강원도 평창군          13
# 16  강원도 홍천군           8
# 17  강원도 화천군           3
# 18  강원도 횡성군          11
# 19  경기도 가평군           9
# 20  경기도 고양시         106
# 21  경기도 과천시          11
# 22  경기도 광명시          17
# 23  경기도 광주시          32
# 24  경기도 구리시          20
# 25  경기도 군포시          14
# 26  경기도 김포시          40
# 27  경기도 남양주시        50
# 28  경기도 동두천시        10
# 29  경기도 부천시          66
# 30  경기도 성남시         109
# ... ...                   ...
# 208 충청남도 금산군        4
# 209 충청남도 논산시       18
# 210 충청남도 당진군       16
# ...

# %%
prov[prov['sigungu'] == '세종특별자치시',]
# Out:
#     sigungu        grdp     income_ct income_personal consumption popl_chong
# 199 세종특별자치시 37.95803 36982.61  19788.8         16762.4     280100
#     popl_male popl_female family
# 199 139734    140366      144275

# %%
data = left_join(prov, hos, key = 'sigungu')[,-c(6,7,8)]
# Out:
# Joining, by = "sigungu"

# %%
data
# Out:
#     sigungu             grdp       income_ct income_personal consumption family
# 1   부산광역시 중구      70.165363 29388.16  19680.32        18029.58     23847
# 2   부산광역시 서구      28.673507 29388.16  19680.32        18029.58     53853
# 3   부산광역시 동구      53.244385 29388.16  19680.32        18029.58     46003
# 4   부산광역시 영도구    20.566487 29388.16  19680.32        18029.58     54903
# 5   부산광역시 부산진구  22.040113 29388.16  19680.32        18029.58    173263
# 6   부산광역시 동래구    14.531938 29388.16  19680.32        18029.58    114987
# 7   부산광역시 남구      21.077476 29388.16  19680.32        18029.58    117876
# 8   부산광역시 북구       9.948792 29388.16  19680.32        18029.58    120668
# 9   부산광역시 해운대구  20.089234 29388.16  19680.32        18029.58    171376
# 10  부산광역시 사하구    20.959316 29388.16  19680.32        18029.58    138854
# 11  부산광역시 금정구    18.894105 29388.16  19680.32        18029.58    107561
# 12  부산광역시 강서구   107.663270 29388.16  19680.32        18029.58     58141
# ...

# %%
write.csv(data, file = 'C:/Users/fleur/2021 P-SAT/주제분석/주제분석 1주차/데이터/province_info.csv', row.names = FALSE)
