# %%
rm(list=ls())

# %%
library(data.table)
library(tidyverse)
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.0 --
#
# √ ggplot2 3.3.3     √ purrr   0.3.4
# √ tibble  3.0.4     √ dplyr   1.0.2
# √ tidyr   1.1.2     √ stringr 1.4.0
# √ readr   1.4.0     √ forcats 0.5.0
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::between()   masks data.table::between()
# x dplyr::filter()    masks stats::filter()
# x dplyr::first()     masks data.table::first()
# x dplyr::lag()       masks stats::lag()
# x dplyr::last()      masks data.table::last()
# x purrr::transpose() masks data.table::transpose()

# %%
setwd('C:/Users/fleur/2021 P-SAT/주제분석/주제분석 1주차/데이터')

# %%
# 데이터
data = fread('provincee.csv', data.table=FALSE)[,-1]

# %%
data
# Out:
#     sigungu  grdp       income_ct income_personal consumption popl_chong
# 1   중구      70.165363 29388.16  19680.32        18029.58     44218
# 2   서구      28.673507 29388.16  19680.32        18029.58    110039
# 3   동구      53.244385 29388.16  19680.32        18029.58     88868
# 4   영도구    20.566487 29388.16  19680.32        18029.58    123521
# 5   부산진구  22.040113 29388.16  19680.32        18029.58    371703
# 6   동래구    14.531938 29388.16  19680.32        18029.58    270727
# 7   남구      21.077476 29388.16  19680.32        18029.58    273854
# 8   북구       9.948792 29388.16  19680.32        18029.58    302924
# 9   해운대구  20.089234 29388.16  19680.32        18029.58    412039
# 10  사하구    20.959316 29388.16  19680.32        18029.58    333301
# 11  금정구    18.894105 29388.16  19680.32        18029.58    244469
# 12  강서구   107.663270 29388.16  19680.32        18029.58    117382
# 13  연제구    31.225310 29388.16  19680.32        18029.58    206742
# ...

# %%
busan_prov = data[1:16,]
chungbuk_prov = data[17:27,]
chungnam_prov = data[28:42,]
daegu_prov = data[43:50,]
daejeon_prov = data[51:55,]
gangwon_prov = data[56:73,]
gwangju_prov = data[74:78,]
gyeongbuk_prov = data[79:101,]
gyeonggi_prov = data[102:132,]
gyeongnam_prov = data[133:150,]
incheon_prov = data[151:160,]
jeju_prov = data[161:162,]
jeonbuk_prov = data[163:176,]
jeonnam_prov = data[177:198,]
sejong_prov = data[199,]
seoul_prov = data[203:227,]
ulsan_prov = data[228:232,]

# %%
# prov 데이터 전부
list_province <- mget(ls(pattern = "_prov"))

for (j in 1:length(list_province)){
    rownames(list_province[[j]]) = NULL
}

list_province %>% names
# Out:
#  [1] "busan_prov"     "chungbuk_prov"  "chungnam_prov"  "daegu_prov"
#  [5] "daejeon_prov"   "gangwon_prov"   "gwangju_prov"   "gyeongbuk_prov"
#  [9] "gyeonggi_prov"  "gyeongnam_prov" "incheon_prov"   "jeju_prov"
# [13] "jeonbuk_prov"   "jeonnam_prov"   "sejong_prov"    "seoul_prov"
# [17] "ulsan_prov"

# %%
# 시도 이름
do = c('부산광역시', '충청북도', '충청남도', '대구광역시', '대전광역시', '강원도',
      '광주광역시', '경상북도', '경기도', '경상남도', '인천광역시', '제주특별자치도', 
       '전라북도', '전라남도', '세종특별자치시', '서울특별시', '울산광역시')

# %%
data0 = data.frame()

for (i in 1:length(list_province)){
    data = list_province[[i]]
    data$sigungu = paste(do[i], data$sigungu)
    
    data0 = rbind(data0, data)
}

# %%
data0
# Out:
#     sigungu             grdp       income_ct income_personal consumption
# 1   부산광역시 중구      70.165363 29388.16  19680.32        18029.58
# 2   부산광역시 서구      28.673507 29388.16  19680.32        18029.58
# 3   부산광역시 동구      53.244385 29388.16  19680.32        18029.58
# 4   부산광역시 영도구    20.566487 29388.16  19680.32        18029.58
# 5   부산광역시 부산진구  22.040113 29388.16  19680.32        18029.58
# 6   부산광역시 동래구    14.531938 29388.16  19680.32        18029.58
# 7   부산광역시 남구      21.077476 29388.16  19680.32        18029.58
# 8   부산광역시 북구       9.948792 29388.16  19680.32        18029.58
# 9   부산광역시 해운대구  20.089234 29388.16  19680.32        18029.58
# 10  부산광역시 사하구    20.959316 29388.16  19680.32        18029.58
# 11  부산광역시 금정구    18.894105 29388.16  19680.32        18029.58
# 12  부산광역시 강서구   107.663270 29388.16  19680.32        18029.58
# 13  부산광역시 연제구    31.225310 29388.16  19680.32        18029.58
# 14  부산광역시 수영구    14.195399 29388.16  19680.32        18029.58
# ...
